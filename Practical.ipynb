# %% [markdown]
# 'telecom.csv'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

# %%
data =pd.read_csv('telecom.csv') 
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7853-GVUDZ  Female              0     Yes        Yes       1
# 1     6893-ODYYE    Male              0      No         No      50
# 2     0486-HECZI    Male              0     Yes         No      55
# 3     8972-HJWNV  Female              1     Yes         No       7
# 4     9317-WZPGV  Female              1      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 5995  2761-OCIAX    Male              1      No         No       2
# 5996  9958-MEKUC    Male              0     Yes        Yes      72
# 5997  7351-KYHQH  Female              1      No         No       7
# 5998  6010-DDPPW    Male              0     Yes         No      70
# 5999  4827-LTQRJ  Female              1     Yes        Yes      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes            No              No  No internet service  ...
# ...

# %% [markdown]
# Split data into 2 parts, take the small one as the final test. You will be using for each model's final evaluation

# %%
df1 = data[0:5000]

# %%
df2= data[5000:6000]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5000  2560-PPCHE  Female              0      No         No      65
# 5001  5084-OOVCJ  Female              0     Yes        Yes      17
# 5002  4256-ZWTZI  Female              0      No        Yes       5
# 5003  6572-ADKRS  Female              0      No         No      46
# 5004  8853-TZDGH  Female              0      No         No      72
# ...          ...     ...            ...     ...        ...     ...
# 5995  2761-OCIAX    Male              1      No         No       2
# 5996  9958-MEKUC    Male              0     Yes        Yes      72
# 5997  7351-KYHQH  Female              1      No         No       7
# 5998  6010-DDPPW    Male              0     Yes         No      70
# 5999  4827-LTQRJ  Female              1     Yes        Yes      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5000          Yes           Yes     Fiber optic                   No  ...
# ...

# %%
def prep(data):
    df= data.copy()
    df = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']]
    df['TotalCharges'] = pd.to_numeric(df[ 'TotalCharges'] , errors="coerce")
    df=df.fillna(np.mean(df))
    df['Churn'] = df[ 'Churn'].map({'Yes': 1, 'No': 0})
    df=pd.get_dummies(df[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']])
    #df1=MinMaxScaler().fit(df) 
    #df=pd.DataFrame(df=df1.transform(df), columns = df.columns)
    
    
    return df

# %%
df = prep(df1)

# %%
y=df['Churn']
X=df.drop(['Churn'],axis=1)

# %%
def kfold(data, model):
    kf=KFold(n_splits=3)
    accuracy_test=[]
    precision_test=[]
    recall_test=[]
    for train_index, test_index in kf.split(data):
        X_train, X_test = data.iloc[train_index], data.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        m=model.fit(X_train, y_train)
        test_predict = model.predict(X_test)
        
        accuracy_test.append(metrics.accuracy_score(y_test, test_predict))
        precision_test.append(metrics.precision_score(y_test, test_predict))
        recall_test.append(metrics.recall_score(y_test, test_predict))
   
    print('accuracy', np.mean(accuracy_test), 'precision',  np.mean(precision_test), 'recall', np.mean(recall_test))

# %% [markdown]
# # Build 5 classification models

# %% [markdown]
# logistic regression, decision tree, random forest, knn, svm

# %% [markdown]
# tips
#
# 1. use cross validation
# 2. use same splits for all classifiers (to have correct comparison)
# 3. build a table to show statistics for all classifiers (at least - accuracy, precision and recall. Any more component would be a +)

# %% [markdown]
# ## Logistic regression

# %%
kfold(X, LogisticRegression())
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## Decision tree

# %%
kfold(X, DecisionTreeClassifier(max_depth=4))
# Out:
# accuracy 0.7956021040689821 precision 0.6432103207061785 recall 0.4865845506246429

# %% [markdown]
# ## Random forest

# %%
kfold(X, RandomForestClassifier(max_depth=4))
# Out:
# accuracy 0.7945994234526443 precision 0.6872793432337136 recall 0.3920112409676937

# %% [markdown]
# ## KNN

# %%
kfold(X, KNeighborsClassifier(n_neighbors=5))
# Out:
# accuracy 0.7625991008280937 precision 0.5558943773307642 recall 0.43571286324229197

# %% [markdown]
# ## SVM

# %%
kfold(X, svm.SVC(kernel='linear'))

# %% [markdown]
# # Test on remaining data

# %%
df_n = prep(df2)
y=df_n['Churn']
X=df_n.drop(['Churn'],axis=1)

# %%
kfold(X, LogisticRegression())
